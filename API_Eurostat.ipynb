# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgenotte/TiVA/blob/main/API_Eurostat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install eurostat

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import eurostat

# %%
# Read the table of contents of the main database and return a dataframe
toc_df = eurostat.get_toc_df()
toc_df
# Out:
#                                                   title  \
# 0     Gross weight of goods transported to/from main...
# 1     Gross weight of goods transported to/from main...
# 2     Gross weight of goods transported to/from main...
# 3     Gross weight of goods transported to/from main...
# 4     Gross weight of goods transported to/from main...
# ...                                                 ...
# 7700  Percentage of letters delivered on-time (USP u...
# 7701                                    Postal services
# 7702    Number of enterprises providing postal services
# 7703  Access points  (USP under direct or indirect d...
# 7704  Domestic postal traffic, letter mail and parce...
#
#                          code     type       last update of data  \
# 0                MAR_GO_AM_ME  dataset  2024-04-22T23:00:00+0200
# 1                MAR_GO_AM_MT  dataset  2010-02-26T23:00:00+0100
# 2                MAR_GO_AM_NL  dataset  2023-11-28T23:00:00+0100
# ...

# %%
# Read the table of contents and return a list of tuples (Specific table)
toc = eurostat.get_toc(dataset='naio_10_fcp_ii3', lang='en')
toc
# Out:
# [('title',
#   'code',
#   'type',
#   'last update of data',
#   'last table structure change',
#   'data start',
#   'data end'),
#  ('EU inter-country input-output table at basic prices, industry by industry (2020 and onwards)',
#   'NAIO_10_FCP_II3',
#   'dataset',
#   '2023-11-18T23:00:00+0100',
#   '2023-12-01T23:00:00+0100',
#   '2020',
#   '2021')]

# %%
type(toc[0])
# Out:
# tuple

# %%
# To get only the metadata of one dataset
toc_sp = eurostat.get_toc_df(dataset='nama_10_gdp', lang='en')
toc_sp
# Out:
#                                                title         code     type  \
# 0  GDP and main components (output, expenditure a...  NAMA_10_GDP  dataset
#
#         last update of data last table structure change data start data end
# 0  2024-05-17T23:00:00+0200    2024-01-15T23:00:00+0100       1975     2023

# %%
# Read the parameter names that can be filtered for a given dataset code and return them as a list.
pars = eurostat.get_pars('naio_10_fcp_ii3')
pars
# Out:
# ['freq', 'ind_use', 'ind_ava', 'c_dest', 'unit', 'c_orig']

# %%
# Read the values of a given parameter par that can be found in a given dataset code
values = eurostat.get_par_values('naio_10_fcp_ii3', 'c_dest')
values
# Out:
# ['BE',
#  'BG',
#  'CZ',
#  'DK',
#  'DE',
#  'EE',
#  'IE',
#  'EL',
#  'ES',
#  'FR',
#  'HR',
#  'IT',
#  'CY',
#  'LV',
#  'LT',
#  'LU',
#  'HU',
#  'MT',
#  'NL',
#  'AT',
#  'PL',
#  'PT',
#  'RO',
#  'SI',
#  'SK',
#  'FI',
#  'SE',
#  'NO',
#  'CH',
#  'UK',
#  'TR',
#  'RU',
#  'ZA',
#  'CA',
#  'US',
#  'MX',
#  'AR',
#  'BR',
#  'CN',
#  'JP',
#  'KR',
#  'IN',
#  'ID',
#  'SA',
#  'AU',
#  'WRL_REST']

# %%
# Get the dictionary of the the parameter values of a dataset as a dataframe
dic = eurostat.get_dic('fats_activ', frmt='df')
dic
# Out:
#          dim                                               name  \
# 0       freq                                     Time frequency
# 1    nace_r2  Statistical classification of economic activit...
# 2  indic_sbs  Economical indicator for structural business s...
# 3     c_ctrl  Country, in which the controlling enterprise i...
# 4        geo                    Geopolitical entity (reporting)
#
#                                                descr
# 0  This code list contains the periodicity that r...
# 1  The Statistical classification of economic act...
# 2  This code list defines the economic indicators...
# 3  This code list contains the country in which t...
# 4  This code list defines the reporting geopoliti...

# %%
# Full download a dataset without flags as pandas dataframe
data = eurostat.get_data_df('fats_activ')
data
# Out:
#         freq  nace_r2       indic_sbs    c_ctrl geo\TIME_PERIOD      2021
# 0          A        B     AV_ENT_TEUR        AT              BA    945.04
# 1          A        B     AV_ENT_TEUR        AT              BG    698.95
# 2          A        B     AV_ENT_TEUR        AT              CZ  16337.74
# 3          A        B     AV_ENT_TEUR        AT              DE       NaN
# 4          A        B     AV_ENT_TEUR        AT       EU27_2020   3437.43
# ...      ...      ...             ...       ...             ...       ...
# 1037175    A  S95_S96  WAGE_LABPRY_PC  WRL_REST              PT    154.87
# 1037176    A  S95_S96  WAGE_LABPRY_PC  WRL_REST              RO    174.48
# 1037177    A  S95_S96  WAGE_LABPRY_PC  WRL_REST              SE    147.35
# 1037178    A  S95_S96  WAGE_LABPRY_PC  WRL_REST              SI    161.43
# 1037179    A  S95_S96  WAGE_LABPRY_PC  WRL_REST              SK       NaN
#
# [1037180 rows x 6 columns]

# %%
code = 'nama_10_gdp'
my_filter_pars = {'geo': 'ES'}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)
data
# Out:
#     freq        unit  na_item geo\TIME_PERIOD  1975  1976  1977  1978  1979  \
# 0      A  CLV05_MEUR      B1G              ES  None  None  None  None  None
# 1      A  CLV05_MEUR     B1GQ              ES  None  None  None  None  None
# 2      A  CLV05_MEUR   D21X31              ES  None  None  None  None  None
# 3      A  CLV05_MEUR       P3              ES  None  None  None  None  None
# 4      A  CLV05_MEUR  P31_S13              ES  None  None  None  None  None
# ..   ...         ...      ...             ...   ...   ...   ...   ...   ...
# 652    A    PYP_MNAC       P7              ES  None  None  None  None  None
# 653    A    PYP_MNAC      P71              ES  None  None  None  None  None
# 654    A    PYP_MNAC      P72              ES  None  None  None  None  None
# 655    A    PYP_MNAC      YA0              ES  None  None  None  None  None
# 656    A    PYP_MNAC      YA1              ES  None  None  None  None  None
#
# ...

# %%
# Download a subset of data from a dataset without flags as pandas dataframe
code = 'naio_10_fcp_ii3'
my_filter_pars = {'c_orig': 'ES', 'c_dest': 'FR', 'ind_use': ['A01','A02','A03'], 'ind_ava': ['A01','A02','A03']}
data = eurostat.get_data_df(code, filter_pars=my_filter_pars)
data
# Out:
#   freq ind_use ind_ava c_dest     unit c_orig\TIME_PERIOD     2020     2021
# 0    A     A01     A01     FR  MIO_EUR                 ES  350.444  416.507
# 1    A     A01     A02     FR  MIO_EUR                 ES    0.007    0.008
# 2    A     A01     A03     FR  MIO_EUR                 ES    0.005    0.005
# 3    A     A02     A01     FR  MIO_EUR                 ES    0.897    1.072
# 4    A     A02     A02     FR  MIO_EUR                 ES    0.884    1.288
# 5    A     A02     A03     FR  MIO_EUR                 ES    0.032    0.034
# 6    A     A03     A01     FR  MIO_EUR                 ES    0.081    0.076
# 7    A     A03     A02     FR  MIO_EUR                 ES    0.000    0.000
# 8    A     A03     A03     FR  MIO_EUR                 ES    0.818    0.854

# %%
suma = data['2020'].sum()
suma
# Out:
# 353.168
